# %% [markdown]
# ## Урок 3. Линейные преобразования

# %%
import numpy as np

# %% [markdown]
# #### 1. Найти собственные векторы и собственные значения для линейного оператора

# %% [markdown]
# ![IMG_1806.jpg](attachment:IMG_1806.jpg)

# %%
A = np.array([[-1, -6], [2, 6]])
w, v = np.linalg.eig(A)

print(f'Матрица A:\n{A}')
print(f'Собственные значения:\n{w}')
print(f'Собственные векторы:\n{v}')
print(f'\nlambda = {w[1]}, x1 = {round(v[0, 1] / v[1,1], 2)} * x2')
print(f'lambda = {w[0]}, x1 = {round(v[0, 0] / v[1,0], 2)} * x2')
# Out:
# Матрица A:
# [[-1 -6]
#  [ 2  6]]
# Собственные значения:
# [2. 3.]
# Собственные векторы:
# [[-0.89442719  0.83205029]
#  [ 0.4472136  -0.5547002 ]]
#
# lambda = 3.0, x1 = -1.5 * x2
# lambda = 2.0, x1 = -2.0 * x2

# %% [markdown]
# #### 2. Дан оператор поворота на 180 градусов, задаваемый матрицей. Показать, что любой вектор является для него собственным.

# %% [markdown]
# Собственный вектор оператора  A  — это такой ненулевой вектор, действие оператора на который сводится к умножению его на число:
# Ax=λx.

# %% [markdown]
# ![IMG_1807.jpg](attachment:IMG_1807.jpg)

# %% [markdown]
# #### 3. Пусть линейный оператор задан матрицей. Установить, является ли вектор  x=(1,1)  собственным вектором этого линейного оператора.

# %% [markdown]
# ![IMG_1808.jpg](attachment:IMG_1808.jpg)

# %%
A = np.array([[1, 1], [-1, 3]])
w, v = np.linalg.eig(A)

print(f'Матрица A:\n{A}')
print(f'Собственные значения:\n{w}')
# Out:
# Матрица A:
# [[ 1  1]
#  [-1  3]]
# Собственные значения:
# [2.00000002 1.99999998]

# %% [markdown]
# #### 4. Пусть линейный оператор задан матрицей. Установить, является ли вектор  x=(3, -3, -4)  собственным вектором этого линейного оператора.

# %% [markdown]
# ![IMG_1809.jpg](attachment:IMG_1809.jpg)

# %%
A = np.array([[0, 3, 0], [3, 0, 0], [0, 0, 3]])
w, v = np.linalg.eig(A)

print(f'Матрица A:\n{A}')
print(f'Собственные значения:\n{w}')
# Out:
# Матрица A:
# [[0 3 0]
#  [3 0 0]
#  [0 0 3]]
# Собственные значения:
# [ 3. -3.  3.]
